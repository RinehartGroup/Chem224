# %% [markdown]
# # Nickel L-edge XAS Analysis
#
# ## Reference
# Gu, Weiwei; Wang, Hongxin; Wang, Kun, Nickel L-edge and K-edge X-ray absorption spectroscopy of non-innocent Ni[S <sub>2</sub> C <sub>2</sub> (CF <sub>3</sub> ) <sub>2</sub> ] <sub>2</sub> <sup>n</sup> series (n = −2, −1, 0): direct probe of nickel fractional oxidation state changes, Dalton Trans., 2014, 43, 6406-6413, DOI: 10.1039/C4DT00308J

# %% [markdown]
# ## Energy Level Diagram
#
# For the nickel L-edge, we're looking at transitions from the 2p orbital to higher energy states.

# %%
# Insert code for generating the energy level diagram here

# %% [markdown]
# ## Simulated XAS Data
#
# Caption: Fig. 1 The wide energy range (a), and the expanded and non-resonant edge jump removed (b) Ni L-edge XAS spectra for complexes 1 (green) 2 (blue), and 3 (red). The L-edge XAS for a reference Ni(I) carbonyl compound (light grey) is shown for comparison (c).

# %%
<div style="text-align: center;">
    <img src="../../images/Capture.PNG" alt="Fig. 1">
    <br>
    <em>Figure 1. The wide energy range (a), and the expanded and non-resonant edge jump removed (b) Ni L-edge XAS spectra for complexes 1 (green) 2 (blue), and 3 (red). The L-edge XAS for a reference Ni(I) carbonyl compound (light grey) is shown for comparison (c). The figure shows features for L_3 and L_2. These edges can be broad and sometimes feature fine structures. In terms of Spectral Theory, the sharp peaks, such as those seen for the L_3 and L_2 features, correspond to the point spectrum and involve transitions to specific, localized unoccupied states. The overall 'edges' (such as the L-edge shown here) represent transitions to a continuum of unoccupied delocalized states, which can be interpreted through the continuous spectrum of spectral theory.</em>
    <br>
    <small>Gu, Weiwei; Wang, Hongxin; Wang, Kun, Nickel L-edge and K-edge X-ray absorption spectroscopy of non-innocent Ni[S <sub>2</sub> C <sub>2</sub> (CF <sub>3</sub> ) <sub>2</sub> ] <sub>2</sub> <sup>n</sup> series (n = −2, −1, 0): direct probe of nickel fractional oxidation state changes, Dalton Trans., 2014, 43, 6406-6413, DOI: 10.1039/C4DT00308J</small>
</div>
# Out:
#   Cell In[1], line 6
#     <small>Gu, Weiwei; Wang, Hongxin; Wang, Kun, Nickel L-edge and K-edge X-ray absorption spectroscopy of non-innocent Ni[S <sub>2</sub> C <sub>2</sub> (CF <sub>3</sub> ) <sub>2</sub> ] <sub>2</sub> <sup>n</sup> series (n = −2, −1, 0): direct probe of nickel fractional oxidation state changes, Dalton Trans., 2014, 43, 6406-6413, DOI: 10.1039/C4DT00308J</small>
#                                                                                                                                                                                                                                  ^
# SyntaxError: invalid character '−' (U+2212)

# %% [markdown]
# ![Fig. 1](Capture.PNG)
